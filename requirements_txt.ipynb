# %% [markdown]
# <a href="https://colab.research.google.com/github/smithblaine014-cyber/irrigation-scheduler/blob/main/requirements_txt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install streamlit
pip install pandas
pip install matplotlib
streamlit
pandas
matplotlib
# Out:
#   File "/tmp/ipykernel_586/823158076.py", line 1
#     pip install streamlit
#         ^
# SyntaxError: invalid syntax
