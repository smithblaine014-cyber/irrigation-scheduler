# %% [markdown]
# <a href="https://colab.research.google.com/github/smithblaine014-cyber/irrigation-scheduler/blob/main/README_md.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Irrigation Scheduler

# Streamlit irrigation scheduling tool using ET and precipitation data.

# Upload a weather dataset with:

# Month
# Date
# Year
# ET_inches
# Precipitation_inches
